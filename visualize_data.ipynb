# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import pandas as pd
from torch_geometric.data import Data, DataLoader
from src.utils import *
from src.architectures import *

# %%
# Data
models = ['GCN', 'SAGE', 'GAT', 'GIN']
random_performance = [49.94, 41.30, 51.15, 49.02]
low_level_performance = [51.10, 47.72, 52.16, 50.15]

# Compute percentage decrease
percentage_decrease = [
    ((rand-low) / low) * 100 for rand, low in zip(random_performance, low_level_performance)
]

# Plotting
x = np.arange(len(models))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, random_performance, width, label='Random')
bars2 = ax.bar(x + width/2, low_level_performance, width, label='Low-Level')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Models')
ax.set_ylabel('Performance')
ax.set_title('Performance Decrease from Low-Level to Random')
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.legend()

# Annotate bars with percentage decrease
for i in range(len(models)):
    ax.annotate(f'{percentage_decrease[i]:.2f}%',
                xy=(x[i], random_performance[i]),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

fig.tight_layout()

plt.show()

# %%
def load_model(model_name, random_feat = False):
    print(f"Let's load {model_name}'s weights...")
    path = './Models/'
    model_data = diz_models[model_name]
    
    path = path + model_data[0]

    if random_feat:
        path += 'True.pt'
    else:
        path += 'False.pt'

    if model_name == 'GAT':
        model = GATSY(n_heads = model_data[1], n_layers = model_data[2])
    elif model_name == 'SAGE':
        model = GraphSage()
    elif model_name == 'GCN':
        model = GCNSY(n_layers=model_data[2])
    elif model_name == 'GIN':
        model = GINSY(n_layers=model_data[2])
    else:
        raise ValueError(f"Model {model_name} not found")

    checkpoint = torch.load(path, map_location=device)
    if isinstance(checkpoint, dict):
        model.load_state_dict(checkpoint)
    else:
        model = checkpoint
    model.to(device)
    return model

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

X = torch.load('data/instance.pt').to(device)      # Instance matrix
A = torch.load('data/adjacencyCOO.pt').to(device)    # Adjacency matrix in the COO format, that is that supported by torch geometric
A1 = torch.load('data/adjacency.pt').to(device)      # Normal adjacency matrix format is obtained with torch.load('adjacency')
num_samples = X.shape[0]
data = Data(x=X, edge_index=A, edge_attr=None, y=None).to(device)

path = './Models/'
diz_models = {
	'GAT': ['GAT_7_3_1_0.001_0.0_triplet_', 1, 3],
	'SAGE': ['SAGE_7_3_0.0001_1e-06_triplet_', 0, 3],
	'GCN': ['GCN_7_3_0.0001_0.0_triplet_', 0, 3],
	'GIN': ['GIN_7_2_0.0001_0.0_triplet_', 0, 2],
}


for mod in diz_models:
    
	print(f"The number of parameters of the {mod} model is {get_n_params(load_model(mod))}")

# %%
data = pd.read_csv('dataset_construction/olga_augmented_labels_.csv')
genres_diz = {}
for i in range(len(data)):

    if not pd.isna(data['genres'][i]):
        genres = eval(data['genres'][i])
        for genre in genres:
            if genre not in genres_diz:
                genres_diz[genre] = 1
            else:
                genres_diz[genre] += 1

# %%
print(genres_diz)
# Out:
# {'classical': 99, 'classical performance': 14, 'german orchestra': 2, 'orchestra': 35, 'olympia wa indie': 7, 'queercore': 6, 'halloween': 2, 'novelty': 4, 'atmospheric black metal': 4, 'blackgaze': 4, 'french black metal': 2, 'french shoegaze': 2, 'gaian doom': 3, 'post-black metal': 1, 'post-metal': 11, 'classic soul': 40, 'northern soul': 121, 'philly soul': 48, 'southern soul': 32, 'latin alternative': 66, 'world': 8, 'bubblegum dance': 7, 'finnish electronic': 1, 'finnish techno': 1, 'minimal dub': 4, 'oakland indie': 2, 'french hip hop': 13, 'old school rap francais': 10, 'pop urbaine': 7, 'brutal death metal': 19, 'death metal': 135, 'deathgrind': 17, 'groove metal': 85, 'metal': 173, 'polish death metal': 2, 'polish metal': 3, 'technical death metal': 12, 'technical groove metal': 1, 'thrash metal': 82, 'bristol electronic': 4, 'drum and bass': 59, 'jump up': 9, 'jungle': 69, 'bubble trance': 11, 'eurodance': 73, 'german dance': 1, 'hands up': 28, 'pop punk': 98, 'jazz trumpet': 15, 'brazilian death metal': 1, 'brazilian metal': 2, 'metal gaucho': 1, 'roots reggae': 148, 'alternative hip hop': 34, 'conscious hip hop': 15, 'oakland hip hop': 7, 'political hip hop': 7, 'hi-nrg': 42, 'hollywood': 7, 'garage punk blues': 3, 'outsider': 7, 'psychobilly': 62, 'punk blues': 12, 'rhythm rock': 1, 'song poem': 2, 'easy listening': 32, 'exotica': 42, 'country': 100, 'country rock': 91, 'outlaw country': 20, 'acoustic rock': 14, 'skate punk': 126, 'dirty south rap': 27, 'gangster rap': 43, 'memphis hip hop': 7, 'rap': 21, 'southern hip hop': 63, 'tennessee hip hop': 1, 'trap': 15, 'deep christian rock': 7, 'rock keyboard': 2, 'deep space rock': 1, 'psych gaze': 5, 'space rock': 109, 'hardcore breaks': 1, 'hardcore techno': 28, 'classic texas country': 18, 'ambient house': 4, 'ambient trance': 2, 'classic progressive house': 8, 'downtempo': 102, 'psychill': 6, 'world fusion': 12, 'big beat': 61, 'soundtrack': 37, 'mexican rock': 30, 'rock en espanol': 22, 'ska mexicano': 3, 'neo soul': 57, 'pop': 27, 'r&b': 59, 'hot jazz': 2, 'jazz trombone': 2, 'vintage jazz': 7, 'doo-wop': 122, 'rhythm and blues': 24, 'melancholia': 35, 'crunk': 33, 'eurotrance': 34, 'happy hardcore': 19, 'latin christian': 1, 'latin worship': 1, 'rock cristiano': 2, "canzone d'autore": 8, 'italian alternative': 8, 'smooth jazz': 104, 'british blues': 14, 'isle of man indie': 2, 'modern blues rock': 14, 'deathrash': 4, 'melodic death metal': 74, 'swedish metal': 10, 'stoner rock': 94, 'sludge metal': 94, 'jazz boom bap': 3, 'rock independant francais': 3, 'hard house': 17, 'trance': 141, 'candy pop': 11, 'pop emo': 13, 'french techno': 2, 'modern ebm': 1, 'techno': 86, 'jangle pop': 157, 'power pop': 172, 'underground power pop': 7, 'piano cover': 1, 'australian hip hop': 2, 'australian underground hip hop': 1, 'neon pop punk': 26, 'minimal techno': 149, 'classic dubstep': 8, 'synthpop': 114, 'ectofolk': 20, 'folk': 140, 'lilith': 25, 'singer-songwriter': 143, 'north carolina indie': 1, 'stomp and holler': 14, 'glam rock': 78, 'mellow gold': 45, 'piano rock': 13, 'rock': 93, 'kizomba antigas': 1, 'zouk': 17, 'swedish ballads': 35, 'german pop': 69, 'vocal jazz': 125, 'chicago rap': 2, 'hardcore hip hop': 39, 'hip hop': 44, 'merseybeat': 16, 'rock-and-roll': 36, 'german metal': 11, 'gothic metal': 86, 'lovecraftian metal': 1, 'dutch pop': 6, 'canadian modern jazz': 1, 'jamaican dancehall': 4, 'modern reggae': 7, 'old school dancehall': 20, 'drone': 122, 'doom metal': 89, 'finnish death metal': 6, 'finnish doom metal': 1, 'finnish melodeath': 5, 'finnish metal': 9, 'phonk': 2, 'broken beat': 7, 'alternative metalcore': 3, 'sasscore': 7, 'screamo': 102, 'skramz': 3, 'funk carioca': 7, 'italian hip hop': 9, 'italian pop': 7, 'electro latino': 3, 'american folk revival': 14, 'native american traditional': 2, 'old school hip hop': 6, 'cali rap': 8, 'hyphy': 19, 'salsa': 73, 'salsa puertorriquena': 3, 'tropical': 11, 'solo wave': 16, 'black metal': 101, 'usbm': 5, 'ret ...
